# %%
# !pip install lmdb
# Out:
# Requirement already satisfied: lmdb in /opt/conda/lib/python3.10/site-packages (1.4.1)

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /opt/conda/lib/python3.10/site-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
import random
import torch
from torch.utils.data import Dataset
from torch.utils.data import sampler
import torchvision.transforms as transforms
import lmdb
import six
import sys
import os
from PIL import Image, ImageDraw, ImageFont
import numpy as np
import string


class ConcatLmdbDataset(Dataset):
    def __init__(self, dataset_list, batchsize_list, 
        ttfRoot=None, corpusRoot=None, transform_img=None,transform_target_img=None, alphabet=string.printable[:-6]):
        #import pdb;pdb.set_trace()
        assert len(dataset_list) == len(batchsize_list)

        if alphabet[-4:] == '.txt':
            alphabet_char = open(alphabet, 'r').read().splitlines()
        alphabet = ''.join(alphabet_char)

        self.corpus = open(corpusRoot, "r").read().splitlines()
        print('Totally %d strings in corpus.' % len(self.corpus))
        
        
        radical_dict = dict()
        total = open('original_data/IDS_dictionary.txt','r').read().splitlines()
        for line in total:
            char,radical = line.split(':')[0],line.split(':')[1]
            radical_dict[char] = radical
        
        if not os.path.isdir(ttfRoot):
            print('%s: the path to *.ttf is not a exist.' % (ttfRoot))
            sys.exit(0)        
        ttf = False
        self.font_path = []
        ttf_dir = os.walk(ttfRoot)
        for path, d, filelist in ttf_dir:
            for filename in filelist:
                if filename.endswith('.ttf') or filename.endswith('.ttc'):
                    self.font_path.append(path+'/'+filename)
                    ttf = True
        if not ttf:
            print('There is no ttf file in the dir.')
            sys.exit(0)
        else:
            print('Totally %d fonts for single character generation.' % len(self.font_path))
        
        self.datasets = []
        self.prob = [batchsize / sum(batchsize_list) for batchsize in batchsize_list]
        for i in range(len(dataset_list)):
            print('For every iter: %s samples from %s' % (batchsize_list[i], dataset_list[i]))
            self.datasets.append(lmdbDataset(dataset_list[i], self.font_path, self.corpus, transform_img,transform_target_img, alphabet,radical_dict))
        self.datasets_range = range(len(self.datasets))

    def __len__(self):
        return max([dataset.__len__() for dataset in self.datasets])

    def __getitem__(self, index):

        idx_dataset = np.random.choice(self.datasets_range, 1, p=self.prob).item()
        idx_sample = index % self.datasets[idx_dataset].__len__()
        #import pdb;pdb.set_trace()
        return self.datasets[idx_dataset][idx_sample]

class lmdbDataset(Dataset):

    def __init__(self, root=None, font_path=None, corpus=None,
        transform_img=None,transform_target_img=None, alphabet=string.printable[:-6], radical_dict = None):
        assert transform_img != None
        self.env = lmdb.open(
            root,
            max_readers=1,
            readonly=True,
            lock=False,
            readahead=False,
            meminit=False)

        if not self.env:
            print('cannot open lmdb from %s' % (root))
            sys.exit(0)

        with self.env.begin(write=False) as txn:
            nSamples = int(txn.get('num-samples'.encode()))
            self.nSamples = nSamples
        
        self.root = root
        self.transform_img = transform_img
        self.transform_target_img = transform_target_img
        self.font_path = font_path
        self.corpus = corpus
        self.alphabet = alphabet
        self.radical_dict = radical_dict
        

    def __len__(self):
        return self.nSamples

    def __getitem__(self, index):
        assert index <= len(self), 'index range error'
        index += 1
        with self.env.begin(write=False) as txn:
            
            label_key = 'label-%09d' % index
            label = str(txn.get(label_key.encode()).decode('utf-8'))
            if label == '##':
                return self[index + 1]

            lexicon_Key = 'lexicon-%09d' % index
            lexicon = str(txn.get(lexicon_Key.encode()).decode('utf-8'))
            space_list = ['⿰','⿱','⿳','⿺','⿶','⿹','⿸','⿵','⿲','⿴','⿷','⿻']
            lexicon_list_old = lexicon.split()
            lexicon_list = []
            for i in lexicon_list_old:
                if i not in space_list:
                    lexicon_list.append(i)
            lexicon = ' '.join(lexicon_list)
         
            img_key = 'image-%09d' % index
            imgbuf = txn.get(img_key.encode())
            buf = six.BytesIO()
            buf.write(imgbuf)
            buf.seek(0)
            try:
                img = Image.open(buf).convert('RGB')
            except IOError:
                print('Corrupted image for %d' % index)
                return self[index + 1]
            
            writerID_key = 'writerID-%09d' % index
            writerID = int(txn.get(writerID_key.encode()))

            font = ImageFont.truetype(self.font_path[random.randint(0,len(self.font_path)-1)], 80)
            label_target = self.corpus[random.randint(0, len(self.corpus)-1)]                        
            lexicon_target = self.radical_dict[label_target]
            lexicon_target_list_old = lexicon_target.split()
            lexicon_target_list = []
            for i in lexicon_target_list_old:
                if i not in space_list:
                    lexicon_target_list.append(i)
            lexicon_target = ' '.join(lexicon_target_list)
            
            try:
                label_w, label_h = font.getsize(label_target)
                img_target = Image.new('RGB', (label_w, label_h), (255, 255, 255))
                drawBrush = ImageDraw.Draw(img_target)
                drawBrush.text((0, 0), label_target, fill=(0, 0, 0), font=font)
                
            except Exception as e:
                with open('failed_font.txt', 'a+') as f:
                    f.write(self.font_path[index % len(self.font_path)] + '\n')
                return self[index + 1]
            
            img_target = self.transform_target_img(img_target)
            img = self.transform_img(img)
            ###################### Target ######################

            return {'A': img, 'B': img_target, 'A_paths': (index-1) % len(self.corpus), 'writerID': writerID,
            'A_label': label, 'B_label': label_target,'root':self.root,'A_lexicon':lexicon,'B_lexicon':lexicon_target}
            

class resizeKeepRatio(object):

    def __init__(self, size, interpolation=Image.BILINEAR, 
        train=False):

        self.size = size
        self.interpolation = interpolation
        self.toTensor = transforms.ToTensor()
        self.train = train

    def __call__(self, img):

        if img.mode == 'L':
            img_result = Image.new("L", self.size, (255))
        elif img.mode =='RGB':
            img_result = Image.new("RGB",self.size, (255, 255, 255))
        else:
            print("Unknow image mode!")

        img_w, img_h = img.size

        target_h = self.size[1]
        target_w = max(1, int(img_w * target_h / img_h))

        if target_w > self.size[0]:
            target_w = self.size[0]

        img = img.resize((target_w, target_h), self.interpolation)
        begin = random.randint(0, self.size[0]-target_w) if self.train else int((self.size[0]-target_w)/2)
        box = (begin, 0, begin+target_w, target_h)
        img_result.paste(img, box)

        img = self.toTensor(img_result)
        img.sub_(0.5).div_(0.5)
        return img

# %%
dataset = ConcatLmdbDataset(
        dataset_list = ['data/FFG_lmdb_dataset_423fonts/test_399fonts_oov_seenstyles_addradical'],
        batchsize_list = [1],
        ttfRoot = 'original_data',
        corpusRoot = "original_data/seen_char.txt",
        transform_img= resizeKeepRatio((128,128)),
        transform_target_img=resizeKeepRatio((128,128)),
        alphabet = "original_data/seen_char.txt",      
    )
# Out:
# Totally 441551 strings in corpus.
# Totally 1 fonts for single character generation.
# For every iter: 1 samples from data/FFG_lmdb_dataset_423fonts/test_399fonts_oov_seenstyles_addradical
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataset = ConcatLmdbDataset(
#       2         dataset_list = ['data/FFG_lmdb_dataset_423fonts/test_399fonts_oov_seenstyles_addradical'],
#       3         batchsize_list = [1],
#       4         ttfRoot = 'original_data',
#       5         corpusRoot = "original_data/seen_char.txt",
#       6         transform_img= resizeKeepRatio((128,128)),
#       7         transform_target_img=resizeKeepRatio((128,128)),
#       8         alphabet = "original_data/seen_char.txt",
#       9     )
#
# Cell In[3], line 56, in ConcatLmdbDataset.__init__(self, dataset_list, batchsize_list, ttfRoot, corpusRoot, transform_img, transform_target_img, alphabet)
#      54 for i in range(len(dataset_list)):
#      55     print('For every iter: %s samples from %s' % (batchsize_list[i], dataset_list[i]))
# ---> 56     self.datasets.append(lmdbDataset(dataset_list[i], self.font_path, self.corpus, transform_img,transform_target_img, alphabet,radical_dict))
#      57 self.datasets_range = range(len(self.datasets))
#
# Cell In[3], line 74, in lmdbDataset.__init__(self, root, font_path, corpus, transform_img, transform_target_img, alphabet, radical_dict)
#      71 def __init__(self, root=None, font_path=None, corpus=None,
#      72     transform_img=None,transform_target_img=None, alphabet=string.printable[:-6], radical_dict = None):
#      73     assert transform_img != None
# ---> 74     self.env = lmdb.open(
#      75         root,
#      76         max_readers=1,
#      77         readonly=True,
#      78         lock=False,
#      79         readahead=False,
#      80         meminit=False)
#      82     if not self.env:
#      83         print('cannot open lmdb from %s' % (root))
#
# Error: data/FFG_lmdb_dataset_423fonts/test_399fonts_oov_seenstyles_addradical: No such file or directory

# %%
root = "original_data"
env = lmdb.open('original_data/data.mdb', readonly=True)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[10], line 2
#       1 root = "original_data"
# ----> 2 env = lmdb.open('original_data/data.mdb', readonly=True)
#
# Error: original_data/data.mdb: Not a directory

# %%
env = lmdb.open('original_data', readonly=True)

# Start a read transaction
with env.begin() as txn:
    # Read a value using a key
    value = txn.get(b'label-000')
    print('Read key1:', value)  # Output: b'value1'

    # Iterate through all key-value pairs
    for key, value in txn.cursor():
        # print('Read:', key, value)
        if 'label' in key:
            break;

# Close the environment
env.close()
# Out:
# Read key1: None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 12
#       9     # Iterate through all key-value pairs
#      10     for key, value in txn.cursor():
#      11         # print('Read:', key, value)
# ---> 12         if 'label' in key:
#      13             break;
#      15 # Close the environment
#
# TypeError: a bytes-like object is required, not 'str'

# %%
index = 400
label_key = 'label-%09d' % index

# %%
label_key
# Out:
# 'label-000000004'

# %%
index = 1111
with env.begin() as txn:
    label_key = 'label-%09d' % index
    label = str(txn.get(label_key.encode()).decode('utf-8'))
    lexicon_Key = 'lexicon-%09d' % index
    lexicon = str(txn.get(lexicon_Key.encode()).decode('utf-8'))
    img_key = 'image-%09d' % index
    imgbuf = txn.get(img_key.encode())
    buf = six.BytesIO()
    buf.write(imgbuf)
    buf.seek(0)
    try:
        img = Image.open(buf).convert('RGB')
    except IOError:
        print('Corrupted image for %d' % index)
    writerID_key = 'writerID-%09d' % index
    writer_id = str(txn.get(writerID_key.encode()).decode('utf-8'))

# %%
writer_id
# Out:
# '8'

# %%
lexicon
# Out:
# 'the'

# %%
label
# Out:
# 'the'

# %%
space_list = ['⿰','⿱','⿳','⿺','⿶','⿹','⿸','⿵','⿲','⿴','⿷','⿻']
lexicon_list_old = lexicon.split()
lexicon_list = []
for i in lexicon_list_old:
    if i not in space_list:
        lexicon_list.append(i)
lexicon = ' '.join(lexicon_list)

# %%
lexicon_list
# Out:
# ['the']

# %%
lexicon
# Out:
# 'the'

# %%
img_key = 'image-%09d' % index
imgbuf = txn.get(img_key.encode())
buf = six.BytesIO()
buf.write(imgbuf)
buf.seek(0)
try:
    img = Image.open(buf).convert('RGB')
except IOError:
    print('Corrupted image for %d' % index)
    return self[index + 1]

# %%
import pandas as pd

# %%
import pandas as pd

try:
    df = pd.read_csv("original_data/iam_dictionary.txt", sep="\t", on_bad_lines='skip')
    print(df.head())  # Display the first few rows of the DataFrame
except FileNotFoundError:
    print("File not found.")
except pd.errors.ParserError as e:
    print(f"ParserError: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ParserError: Error tokenizing data. C error: EOF inside string starting at row 1

# %%
radical_dict = dict()
total = open('original_data/IDS_dictionary.txt','r').read().splitlines()
for line in total:
    char,radical = line.split(':')[0],line.split(':')[1]
    radical_dict[char] = radical

# %%
radical_dict
# Out:
# {'说': '⿰ 讠 ⿱ 丷 ⿱ 口 儿 ',
#  '㐻': '⿰ 亻 内 ',
#  '蓳': '⿱ 艹 ⿱ 廿 ⿻ 口 龶 ',
#  '䆎': '⿰ 禾 ⿹ ⿶ 戈 ⿰ 人 人 ⿱ 非 一 ',
#  '喹': '⿰ 口 ⿱ 大 ⿱ 土 土 ',
#  '窛': '⿱ ⿱ 宀 八 ⿺ ⿱ 一 兀 女 ',
#  '霎': '⿱ 雨 ⿱ 立 女 ',
#  '㞡': '⿸ 尸 ⿱ ⿱ ⿰ 工 工 ⿰ 工 工 𧘇 ',
#  '児': '⿱ ⿰ 丨 日 儿 ',
#  '忛': '⿰ 忄 ⿵ 几 丶 ',
#  '諓': '⿰ 言 ⿱ 戈 戈 ',
#  '胘': '⿰ 月 ⿱ 亠 幺 ',
#  '䌘': '⿱ ⿰ 㡀 攵 糸 ',
#  '䀕': '⿰ 目 ⿰ 弓 丨 ',
#  '銜': '⿲ 彳 金 ⿱ 一 丁 ',
#  '柴': '⿱ ⿰ 止 匕 木 ',
#  '䞷': '⿺ ⿱ 土 龰 ⿸ 尸 ⿱ ⿻ 凵 丨 凵 ',
#  '袚': '⿰ 衤 ⿺ ⿸ 𠂇 又 丶 ',
#  '婼': '⿰ 女 ⿱ 艹 ⿸ 𠂇 口 ',
#  '管': '⿱ 竹 ⿱ 宀 㠯 ',
#  '层': '⿸ 尸 ⿱ 二 厶 ',
#  '䂥': '⿰ 石 民 ',
#  '構': '⿰ 木 ⿱ ⿱ 井 一 冉 ',
#  '趐': '⿺ ⿱ 土 龰 ⿰ 习 习 ',
#  '怇': '⿰ 忄 巨 ',
#  '懣': '⿱ ⿰ 氵 ⿱ 廿 ⿻ 巾 ⿰ 入 入 心 ',
#  '垁': '⿰ 土 ⿱ 𠂉 大 ',
#  '㬅': '⿳ 日 罒 方 ',
#  '㥋': '⿱ ⿰ 亻 衣 心 ',
#  '裒': '⿳ 亠 臼 𧘇 ',
#  '彙': '⿳ 彑 冖 果 ',
#  '䠋': '⿰ ⿱ 口 止 ⿱ ⿻ 白 丿 十 ',
#  '胝': '⿰ 月 ⿱ 氏 丶 ',
#  '䨵': '⿱ 雨 ⿰ 氵 ⿱ 覀 ⿱ 日 十 ',
#  '㹾': '⿰ 犭 ⿱ ⿺ 夂 卜 口 ',
#  '嬑': '⿰ 女 ⿱ ⿱ 立 日 心 ',
#  '碸': '⿰ 石 ⿵ 几 ⿱ 丿 虫 ',
#  '嗭': '⿱ ⿱ 十 ⿴ 且 一 ⿰ 口 ⿻ 乚 丿 ',
#  '昉': '⿰ 日 方 ',
#  '戹': '⿸ 户 乙 ',
#  '壁': '⿱ ⿰ ⿸ 尸 口 ⿱ 立 十 土 ',
#  '曹': '⿱ ⿻ 一 曲 日 ',
#  '偁': '⿰ 亻 ⿱ 爫 冉 ',
#  '䛲': '⿰ 言 ⿱ 白 巾 ',
#  '贙': '⿱ ⿰ ⿸ 虍 几 ⿸ 虍 几 ⿱ 目 八 ',
#  '䀢': '⿰ 目 ⿱ 𠂉 大 ',
#  '㚛': '⿱ 大 ⿱ 匕 日 ',
#  '萎': '⿱ 艹 ⿱ 禾 女 ',
#  '儬': '⿰ 亻 ⿰ ⿱ 龶 月 ⿱ 目 儿 ',
#  '袦': '⿰ 衤 ⿱ ⿻ 凵 丨 凵 ',
#  '疤': '⿸ 疒 巴 ',
#  '巆': '⿰ 山 ⿱ ⿱ ⿰ 火 火 冖 ⿳ 口 丿 口 ',
#  '弜': '⿰ 弓 弓 ',
#  '攠': '⿰ 扌 ⿸ ⿸ 广 ⿰ 木 木 非 ',
#  '擌': '⿰ 扌 ⿱ 竹 ⿻ 大 ⿰ 人 人 ',
#  '㴈': '⿰ 氵 ⿱ 丘 山 ',
#  '苑': '⿱ 艹 ⿰ 夕 㔾 ',
#  '䁆': '⿰ 目 ⿱ 大 电 ',
#  '玦': '⿰ 王 夬 ',
#  '疅': '⿰ 田 ⿳ ⿱ 一 田 ⿱ 一 田 一 ',
#  '渥': '⿰ 氵 ⿸ 尸 ⿱ ⿱ 一 厶 土 ',
#  '病': '⿸ 疒 ⿱ 一 内 ',
#  '狻': '⿰ 犭 ⿳ 厶 八 夂 ',
#  '蹜': '⿰ ⿱ 口 止 ⿱ 宀 ⿰ 亻 ⿱ 一 白 ',
#  '檾': '⿱ ⿱ ⿰ 火 火 冖 ⿰ 木 木 ',
#  '諦': '⿰ 言 ⿱ ⿱ ⿱ 亠 丷 冖 巾 ',
#  '倪': '⿰ 亻 ⿱ 臼 儿 ',
#  '鏦': '⿰ 金 ⿰ 彳 ⿱ ⿰ 人 人 龰 ',
#  '㝼': '⿺ 尢 于 ',
#  '捦': '⿰ 扌 金 ',
#  '酏': '⿰ 酉 也 ',
#  '搯': '⿰ 扌 ⿱ 爫 臼 ',
#  '㧒': '⿰ 扌 ⿱ 宀 八 ',
#  '衊': '⿰ ⿱ 丿 皿 ⿱ ⿱ 艹 罒 ⿵ 戊 丶 ',
#  '汋': '⿰ 氵 ⿹ 勹 丶 ',
#  '篵': '⿱ 竹 ⿰ 彳 ⿱ ⿰ 人 人 龰 ',
#  '士': '⿱ 十 一 ',
#  '㸮': '⿰ 牛 ⿱ 八 刀 ',
#  '㺊': '⿰ 犭 ⿱ ⿱ 䒑 土 心 ',
#  '弭': '⿰ 弓 耳 ',
#  '焑': '⿰ 火 ⿴ 囗 木 ',
#  '粐': '⿰ 米 户 ',
#  '茔': '⿱ ⿱ 艹 冖 土 ',
#  '彪': '⿺ ⿸ 虍 几 彡 ',
#  '皘': '⿰ 白 ⿱ 龶 月 ',
#  '瘮': '⿸ 疒 ⿱ ⿱ ⿱ 厶 ⿰ 厶 厶 人 彡 ',
#  '籝': '⿱ 竹 ⿱ ⿱ 亡 口 ⿲ 月 女 ⿵ 几 丶 ',
#  '掜': '⿰ 扌 ⿱ 臼 儿 ',
#  '桞': '⿰ 木 ⿰ 夕 阝 ',
#  '㞁': '⿺ 尢 ⿱ 日 匕 ',
#  '巒': '⿱ ⿲ 糸 言 糸 山 ',
#  '禖': '⿰ 礻 ⿱ 甘 木 ',
#  '䖞': '⿰ 虫 寸 ',
#  '抇': '⿰ 扌 日 ',
#  '响': '⿰ 口 ⿵ ⿱ 丿 冂 口 ',
#  '麯': '⿰ ⿱ ⿻ 木 ⿰ 人 人 夂 曲 ',
#  '厸': '⿰ 厶 厶 ',
#  '隰': '⿰ 阝 ⿱ 日 ⿱ ⿰ 幺 幺 灬 ',
#  '㝱': '⿱ 宀 ⿰ 爿 ⿳ ⿱ 艹 罒 冖 夕 ',
#  '䊙': '⿱ ⿰ 石 ⿱ 一 廾 米 ',
#  '衄': '⿰ ⿱ 丿 皿 丑 ',
#  '披': '⿰ 扌 皮 ',
#  '墩': '⿰ 土 ⿰ ⿳ 亠 口 子 攵 ',
#  '庺': '⿸ 广 ⿱ ⿱ 八 厶 木 ',
#  '蘟': '⿱ 艹 ⿰ 阝 ⿱ ⿳ 爫 工 彐 心 ',
#  '螶': '⿱ 巨 ⿰ 虫 虫 ',
#  '纥': '⿰ 纟 ⿱ 𠂉 乙 ',
#  '撽': '⿰ 扌 ⿰ ⿱ 白 方 攵 ',
#  '㴄': '⿰ 氵 ⿴ 四 冂 ',
#  '覢': '⿰ ⿱ 火 火 ⿱ 目 儿 ',
#  '咯': '⿰ 口 ⿱ 夂 口 ',
#  '蛄': '⿰ 虫 ⿱ 十 口 ',
#  '㠼': '⿰ 巾 斤 ',
#  '虓': '⿰ 九 ⿸ 虍 几 ',
#  '碔': '⿰ 石 ⿹ ⿶ 弋 一 止 ',
#  '錉': '⿰ 金 ⿱ 氏 日 ',
#  '柧': '⿰ 木 瓜 ',
#  '郣': '⿰ ⿱ ⿱ 十 冖 子 阝 ',
#  '䓍': '⿱ 艹 ⿱ 日 干 ',
#  '僋': '⿰ 亻 ⿱ ⿱ ⿱ 人 丶 ㇇ ⿱ 目 八 ',
#  '滜': '⿰ 氵 ⿱ 白 ⿱ 大 十 ',
#  '㹿': '⿰ 犭 ⿱ ⺊ ⿱ 日 十 ',
#  '薗': '⿱ 艹 ⿴ 囗 ⿱ ⿱ 土 口 𧘇 ',
#  '囐': '⿰ 口 ⿰ ⿸ 虍 ⿳ 一 口 ⿵ ⿵ 冂 儿 ⿱ 一 丨 犬 ',
#  '囡': '⿴ 囗 女 ',
#  '茭': '⿱ 艹 ⿱ 亠 父 ',
#  '䩠': '⿰ 革 ⿺ 廴 ⿱ 丿 士 ',
#  '峿': '⿰ 山 ⿱ 五 口 ',
#  '膭': '⿰ 月 ⿱ ⿱ 中 一 ⿱ 目 八 ',
#  '婺': '⿱ ⿰ 矛 攵 女 ',
#  '徖': '⿰ 彳 ⿱ 宀 示 ',
#  '饿': '⿰ 饣 我 ',
#  '㶫': '⿱ ⿻ 大 丷 火 ',
#  '塤': '⿰ 土 ⿱ 口 ⿱ 目 八 ',
#  '㴠': '⿰ 氵 ⿶ 凵 ⿻ 了 ⿰ 口 又 ',
#  '畉': '⿰ 田 夫 ',
#  '勿': '⿹ 勹 ⿱ 丿 丿 ',
#  '䍀': '⿰ 纟 ⿱ ⿰ 〢 ⿱ 𠂉 丶 皿 ',
#  '㫘': '⿱ 不 日 ',
#  '捜': '⿰ 扌 ⿱ 申 又 ',
#  '霗': '⿱ 雨 ⿰ 氵 ⿱ ⿱ 人 丶 龴 ',
#  '脌': '⿰ 月 年 ',
#  '皽': '⿰ ⿱ ⿱ 亠 ⿴ 囗 口 ⿱ 日 一 皮 ',
#  '怗': '⿰ 忄 ⿱ ⺊ 口 ',
#  '㵳': '⿰ 氵 ⿱ 宀 ⿱ ⿰ 习 习 ⿱ 人 彡 ',
#  '擈': '⿰ 扌 ⿱ 业 ⿱ 䒑 未 ',
#  '鍊': '⿰ 金 柬 ',
#  '禐': '⿰ 礻 ⿳ 爫 一 ⿸ 𠂇 又 ',
#  '艫': '⿰ 舟 ⿸ 虍 ⿱ 田 皿 ',
#  '㼫': '⿰ 果 瓦 ',
#  '彩': '⿰ ⿱ 爫 木 彡 ',
#  '䒸': '⿱ 艹 ⿱ 丿 皿 ',
#  '訷': '⿰ 言 申 ',
#  '瞓': '⿰ 目 ⿰ 言 川 ',
#  '淁': '⿰ 氵 ⿱ 立 女 ',
#  '蝘': '⿰ 虫 ⿷ 匚 ⿱ 日 女 ',
#  '傖': '⿰ 亻 ⿱ ⿱ 人 丶 ⿸ ⿴ 尸 一 口 ',
#  '旺': '⿰ 日 王 ',
#  '嬂': '⿰ 女 ⿹ ⿶ 戈 ⿱ 亠 丷 日 ',
#  '㶈': '⿰ 氵 ⿱ ⿱ ⿰ 火 火 冖 虫 ',
#  '袡': '⿰ 衤 冉 ',
#  '偠': '⿰ 亻 ⿱ 覀 女 ',
#  '岊': '⿱ 巴 山 ',
#  '缓': '⿰ 纟 ⿳ 爫 一 ⿸ 𠂇 又 ',
#  '瘘': '⿸ 疒 ⿱ 米 女 ',
#  '蕞': '⿱ 艹 ⿱ 日 ⿰ 耳 又 ',
#  '㻅': '⿰ 王 ⿱ 人 ⿱ 二 厶 ',
#  '箷': '⿱ 竹 ⿰ 方 ⿱ 𠂉 也 ',
#  '䇸': '⿱ 竹 ⿱ 口 王 ',
#  '刾': '⿰ ⿻ 夫 丷 刂 ',
#  '䨧': '⿱ 雨 ⿰ 立 ⿱ ⿱ 人 丶 龴 ',
#  '刪': '⿰ ⿻ ⿵ 冂 ⿰ 丨 丨 一 刂 ',
#  '崹': '⿰ 山 ⿱ ⿱ ⿱ 亠 丷 冖 巾 ',
#  '仼': '⿰ 亻 王 ',
#  '㽢': '⿰ 田 ⿱ 大 电 ',
#  '坛': '⿰ 土 ⿱ 二 厶 ',
#  '吱': '⿰ 口 ⿱ 十 又 ',
#  '郯': '⿰ ⿱ 火 火 阝 ',
#  '㝒': '⿱ 宀 ⿱ 十 口 ',
#  '吙': '⿰ 口 火 ',
#  '唘': '⿱ ⿰ 石 又 口 ',
#  '琕': '⿰ 王 ⿱ ⿻ 白 丿 十 ',
#  '䞄': '⿱ ⿰ 方 ⿱ 𠂉 也 ⿱ 目 八 ',
#  '堎': '⿰ 土 ⿳ 土 八 夂 ',
#  '汦': '⿰ 氵 氏 ',
#  '銾': '⿰ 金 ⿱ 工 水 ',
#  '幔': '⿰ 巾 ⿳ 日 罒 又 ',
#  '衅': '⿰ ⿱ 丿 皿 ⿱ 丷 ⿻ 二 丨 ',
#  '兵': '⿱ 丘 八 ',
#  '㚎': '⿱ 大 凵 ',
#  '绶': '⿰ 纟 ⿱ ⿱ 爫 冖 又 ',
#  '邷': '⿰ 瓦 阝 ',
#  '艑': '⿰ 舟 ⿸ 户 ⿵ 冂 卄 ',
#  '䁟': '⿰ 目 ⿸ 羊 工 ',
#  '䬓': '⿺ ⿵ 几 ⿱ 丿 虫 ⿱ 立 日 ',
#  '扙': '⿰ 扌 丈 ',
#  '䅚': '⿰ 禾 ⿱ ⿱ 丷 夫 㔾 ',
#  '僭': '⿰ 亻 ⿱ ⿰ 旡 旡 日 ',
#  '慵': '⿰ 忄 ⿸ 广 ⿻ 肀 月 ',
#  '㖡': '⿰ 口 ⿱ 亠 ⿰ 亻 ⿴ 夂 丶 ',
#  '采': '⿱ 爫 木 ',
#  '贤': '⿱ ⿰ 〢 又 贝 ',
#  '杍': '⿰ 木 子 ',
#  '舶': '⿰ 舟 白 ',
#  '敲': '⿰ ⿳ 亠 口 ⿵ 冂 口 ⿱ ⺊ 又 ',
#  '逰': '⿺ 辶 ⿰ 扌 ⿱ 𠂉 子 ',
#  '撂': '⿰ 扌 ⿱ 田 ⿱ 夂 口 ',
#  '砨': '⿰ 石 ⿸ 户 乙 ',
#  '醩': '⿰ 酉 ⿱ ⿻ 一 曲 日 ',
#  '圡': '⿷ 土 丶 ',
#  '峅': '⿰ 山 ⿱ 厶 廾 ',
#  '求': '⿺ ⿻ 一 氺 丶 ',
#  '阮': '⿰ 阝 ⿱ 一 兀 ',
#  '拸': '⿰ 扌 ⿱ 夕 夕 ',
#  '鋖': '⿰ 金 ⿱ 爫 女 ',
#  '㳮': '⿰ 氵 ⿸ 尸 水 ',
#  '䒰': '⿱ 艹 ⿷ 匚 王 ',
#  '猆': '⿱ 非 犬 ',
#  '翍': '⿰ ⿰ 习 习 皮 ',
#  '選': '⿺ 辶 ⿱ ⿰ 巳 巳 ⿱ 龷 八 ',
#  '埪': '⿰ 土 ⿱ ⿱ 宀 八 工 ',
#  '剨': '⿰ ⿱ 丰 石 刂 ',
#  '禑': '⿰ 礻 禺 ',
#  '哵': '⿰ 口 ⿰ ⿱ 口 力 刂 ',
#  '阿': '⿰ 阝 ⿹ 丁 口 ',
#  '豹': '⿰ 豸 ⿹ 勹 丶 ',
#  '翣': '⿱ ⿰ 习 习 ⿱ 立 女 ',
#  '沥': '⿰ 氵 ⿸ 厂 力 ',
#  '朏': '⿰ 月 ⿱ ⿻ 凵 丨 凵 ',
#  '卨': '⿱ ⺊ ⿵ 冎 口 ',
#  '狧': '⿰ 犭 ⿱ 千 口 ',
#  '㳉': '⿰ 氵 月 ',
#  '圜': '⿴ 囗 ⿳ 罒 ⿱ 一 口 𧘇 ',
#  '㡏': '⿰ 巾 ⿱ ⿱ 人 一 ⿰ 月 刂 ',
#  '姗': '⿰ 女 册 ',
#  '訯': '⿰ 言 及 ',
#  '䦼': '⿰ 阝 夬 ',
#  '胕': '⿰ 月 ⿰ 亻 寸 ',
#  '㤏': '⿰ 忄 ⿱ 夂 ⺀ ',
#  '䆃': '⿱ ⿺ 辶 ⿱ 䒑 自 禾 ',
#  '㑃': '⿰ 亻 ⿰ 幺 力 ',
#  '倜': '⿰ 亻 ⿵ ⺆ ⿱ 土 口 ',
#  '貀': '⿰ 豸 ⿱ ⿻ 凵 丨 凵 ',
#  '蟞': '⿱ ⿰ 㡀 攵 虫 ',
#  '醦': '⿰ 酉 ⿱ ⿱ ⿱ 厶 ⿰ 厶 厶 人 彡 ',
#  '姸': '⿰ 女 ⿰ 干 干 ',
#  '稂': '⿰ 禾 ⿱ 丶 艮 ',
#  '擅': '⿰ 扌 ⿱ ⿱ 亠 ⿴ 囗 口 ⿱ 日 一 ',
#  '孞': '⿱ 子 心 ',
#  '㾠': '⿸ 疒 ⿰ 犭 王 ',
#  '任': '⿰ 亻 ⿱ 丿 士 ',
#  '㹖': '⿰ 牛 ⿱ ⿱ 丷 夫 豕 ',
#  '惷': '⿱ ⿱ 𡗗 日 心 ',
#  '硪': '⿰ 石 我 ',
#  '㾤': '⿸ 疒 ⿱ ⿱ 宀 八 工 ',
#  '偆': '⿰ 亻 ⿱ 𡗗 日 ',
#  '乨': '⿰ ⿱ 厶 口 乚 ',
#  '戊': '戊 ',
#  '敗': '⿰ ⿱ 目 八 攵 ',
#  '濵': '⿰ 氵 ⿱ 宀 ⿸ 𠃜 ⿱ 目 八 ',
#  '㚽': '⿱ ⿰ 工 丂 女 ',
#  '绵': '⿰ 纟 ⿱ 白 巾 ',
#  '帕': '⿰ 巾 白 ',
#  '堘': '⿰ 土 ⿱ ⿱ 丷 夫 土 ',
#  '霦': '⿱ 雨 ⿰ ⿰ 木 木 彡 ',
#  '䏉': '⿰ 耳 ⿱ 日 ⿱ ⿰ 幺 幺 灬 ',
#  '疨': '⿸ 疒 牙 ',
#  '㪂': '⿰ 气 ⿱ ⺊ 又 ',
#  '粀': '⿰ 米 丈 ',
#  '㔭': '⿰ 匕 ⿱ 日 ⿱ 一 龰 ',
#  '吀': '⿰ 口 千 ',
#  '苓': '⿱ 艹 ⿱ ⿱ 人 丶 龴 ',
#  '龬': '⿰ 金 ⿵ 冂 ⿱ 䒑 亡 ',
#  '疾': '⿸ 疒 ⿱ 𠂉 大 ',
#  '熯': '⿰ 火 ⿱ 廿 ⿻ 口 夫 ',
#  '抓': '⿰ 扌 爪 ',
#  '莝': '⿱ 艹 ⿻ 土 ⿰ 人 人 ',
#  '䵉': '⿸ ⿸ 广 ⿰ 木 木 ⿱ ⿱ 人 一 ⿰ 月 刂 ',
#  '嘓': '⿰ 口 ⿴ 囗 ⿹ 戈 ⿱ 口 一 ',
#  '榘': '⿱ ⿰ ⿱ 𠂉 大 巨 木 ',
#  '捌': '⿰ 扌 ⿰ ⿱ 口 力 刂 ',
#  '糟': '⿰ 米 ⿱ ⿻ 一 曲 日 ',
#  '潥': '⿰ 氵 ⿱ 覀 米 ',
#  '账': '⿰ 贝 长 ',
#  '曘': '⿰ 日 ⿱ 雨 而 ',
#  '賁': '⿱ ⿱ 十 廾 ⿱ 目 八 ',
#  '呵': '⿰ 口 ⿹ 丁 口 ',
#  '礚': '⿰ 石 ⿱ 艹 ⿱ ⿱ 土 厶 皿 ',
#  '泖': '⿰ 氵 卯 ',
#  '恄': '⿰ 忄 ⿱ 士 口 ',
#  '洲': '⿰ 氵 州 ',
#  '徝': '⿰ 彳 ⿱ 十 ⿴ 且 一 ',
#  '诓': '⿰ 讠 ⿷ 匚 王 ',
#  '黛': '⿱ ⿰ 亻 弋 黑 ',
#  '柭': '⿰ 木 ⿺ ⿸ 𠂇 又 丶 ',
#  '蝇': '⿰ 虫 ⿱ 口 电 ',
#  '㯐': '⿱ ⿰ 阝 ⿱ ⿸ 𠂇 工 月 木 ',
#  '認': '⿰ 言 ⿱ ⿹ 刀 丿 心 ',
#  '辝': '⿰ ⿱ 厶 口 ⿱ 立 十 ',
#  '缶': '缶 ',
#  '敬': '⿰ ⿱ 艹 ⿹ 勹 口 攵 ',
#  '暴': '⿱ 日 ⿱ ⿱ 龷 八 氺 ',
#  '队': '⿰ 阝 人 ',
#  '扡': '⿰ 扌 也 ',
#  '覑': '⿰ 片 ⿱ 目 儿 ',
#  '䤹': '⿰ 金 ⿱ 宀 ⿱ 火 又 ',
#  '銐': '⿱ ⿰ 歹 刂 金 ',
#  '淦': '⿰ 氵 金 ',
#  '忳': '⿰ 忄 屯 ',
#  '磊': '⿱ 石 ⿰ 石 石 ',
#  '跑': '⿰ ⿱ 口 止 ⿹ 勹 巳 ',
#  '㡉': '⿰ 巾 ⿰ 弓 ⿱ 亠 幺 ',
#  '筥': '⿱ 竹 ⿱ 口 口 ',
#  '茀': '⿱ 艹 弗 ',
#  '痰': '⿸ 疒 ⿱ 火 火 ',
#  '㽺': '⿸ 疒 及 ',
#  '抛': '⿰ 扌 ⿺ 九 力 ',
#  '盻': '⿰ 目 ⿱ 八 丂 ',
#  '铸': '⿰ 钅 ⿸ 丰 寸 ',
#  '䧎': '⿰ 阝 ⿱ 口 月 ',
#  '挅': '⿰ 扌 ⿱ 乃 木 ',
#  '錜': '⿰ 金 ⿱ ⿱ ⿱ 人 丶 ㇇ 心 ',
#  '剪': '⿱ ⿱ 䒑 ⿰ 月 刂 刀 ',
#  '聟': '⿱ ⿰ ⿱ 𠂉 大 口 耳 ',
#  '仂': '⿰ 亻 力 ',
#  '鬁': '⿱ ⿰ 镸 彡 ⿰ 禾 刂 ',
#  '䅓': '⿲ 禾 ⿹ 勹 口 又 ',
#  '语': '⿰ 讠 ⿱ 五 口 ',
#  '秢': '⿰ 禾 ⿱ ⿱ 人 丶 龴 ',
#  '鍅': '⿰ 金 ⿰ 氵 ⿱ 土 厶 ',
#  '園': '⿴ 囗 ⿱ ⿱ 土 口 𧘇 ',
#  '隦': '⿰ 阝 ⿰ ⿸ 尸 口 ⿱ 立 十 ',
#  '婝': '⿰ 女 ⿱ 宀 ⿱ 一 龰 ',
#  '耼': '⿰ 耳 ⿻ 冂 二 ',
#  '䘀': '⿱ ⿱ 𠂤 十 ⿰ 虫 虫 ',
#  '鬃': '⿱ ⿰ 镸 彡 ⿱ 宀 示 ',
#  '髿': '⿱ ⿰ 镸 彡 ⿰ 氵 ⿱ 小 丿 ',
#  '岪': '⿱ 山 弗 ',
#  '缨': '⿰ 纟 ⿱ ⿰ 贝 贝 女 ',
#  '㴪': '⿰ 氵 ⿱ 自 木 ',
#  '掽': '⿰ 扌 ⿱ 䒑 业 ',
#  '烖': '⿹ ⿶ 戈 十 火 ',
#  '㛢': '⿰ 女 ⿱ 禾 乃 ',
#  '䭫': '⿰ ⿱ 匕 日 ⿱ 䒑 自 ',
#  '翅': '⿺ ⿱ 十 又 ⿰ 习 习 ',
#  '帞': '⿰ 巾 ⿱ 一 白 ',
#  '拰': '⿰ 扌 ⿰ 亻 ⿱ 丿 士 ',
#  '麦': '⿱ 龶 夂 ',
#  '踗': '⿰ ⿱ 口 止 ⿱ ⿱ ⿱ 人 丶 ㇇ 心 ',
#  '㛘': '⿰ 女 ⿱ ⿱ 十 冖 子 ',
#  '䅎': '⿰ 禾 ⿱ 禾 乃 ',
#  '㐹': '⿰ 亻 气 ',
#  '橣': '⿰ 木 ⿱ ⿱ 宀 心 ⿵ 冂 ⿻ 二 丨 ',
#  '夺': '⿱ 大 寸 ',
#  '踇': '⿰ ⿱ 口 止 ⿱ 𠂉 母 ',
#  '喳': '⿰ 口 ⿱ 木 ⿱ 日 一 ',
#  '䠛': '⿰ ⿱ 口 止 ⿱ 爫 缶 ',
#  '㚦': '⿰ 女 丌 ',
#  '䣉': '⿱ ⿰ 氵 ⿱ 小 丿 ⿱ 口 巴 ',
#  '撁': '⿰ 扌 ⿱ ⿱ 亠 ⿻ 幺 冖 牛 ',
#  '摄': '⿰ 扌 ⿱ 耳 ⿰ 又 又 ',
#  '㐡': '⿺ 九 ⿱ 而 大 ',
#  '旖': '⿰ 方 ⿱ 𠂉 ⿱ 大 ⿹ 丁 口 ',
#  '㖵': '⿰ 口 ⿱ ⿴ 且 一 八 ',
#  '捊': '⿰ 扌 ⿱ 爫 子 ',
#  '樂': '⿱ ⿲ 幺 白 幺 木 ',
#  '坭': '⿰ 土 ⿸ 尸 匕 ',
#  '㹗': '⿰ 牛 ⿳ ⿳ 士 乛 工 一 ⿰ 口 寸 ',
#  '䅼': '⿰ 禾 ⿳ 日 罒 又 ',
#  '側': '⿰ 亻 ⿰ ⿱ 目 八 刂 ',
#  '䐕': '⿰ 月 ⿱ 口 耳 ',
#  '鈛': '⿰ 金 戈 ',
#  '琾': '⿰ 王 ⿱ 田 ⿱ 人 ⿰ 丿 丨 ',
#  '甸': '⿹ 勹 田 ',
#  '箪': '⿱ 竹 ⿱ 丷 ⿻ 甲 一 ',
#  '酣': '⿰ 酉 甘 ',
#  '枘': '⿰ 木 内 ',
#  '撢': '⿰ 扌 ⿱ 覀 ⿱ 日 十 ',
#  '踕': '⿰ ⿱ 口 止 疌 ',
#  '鋭': '⿰ 金 ⿱ 丷 ⿱ 口 儿 ',
#  '霩': '⿱ 雨 ⿰ ⿳ 亠 口 子 阝 ',
#  '彫': '⿰ ⿵ ⺆ ⿱ 土 口 彡 ',
#  '丆': '⿱ 一 丿 ',
#  '螛': '⿰ 虫 ⿱ ⿱ 宀 丰 口 ',
#  '壙': '⿰ 土 ⿸ 广 ⿳ 龷 由 八 ',
#  '裌': '⿰ 衤 ⿻ 大 ⿰ 人 人 ',
#  '怼': '⿱ ⿰ 又 寸 心 ',
#  '訃': '⿰ 言 卜 ',
#  '澫': '⿰ 氵 ⿱ 艹 禺 ',
#  '椫': '⿰ 木 ⿱ 丷 ⿻ 甲 一 ',
#  '䀖': '⿰ 目 ⿱ 一 大 ',
#  '锬': '⿰ 钅 ⿱ 火 火 ',
#  '腡': '⿰ 月 ⿵ 冎 口 ',
#  '粈': '⿰ 米 丑 ',
#  '掆': '⿰ 扌 ⿵ 冂 ⿱ 䒑 山 ',
#  '毡': '⿺ 毛 ⿱ ⺊ 口 ',
#  '㣵': '⿰ 彳 ⿺ 辶 ⿱ 土 羊 ',
#  '丢': '⿱ 丿 ⿱ 土 厶 ',
#  '赻': '⿺ ⿱ 土 龰 ⿱ 小 丿 ',
#  '遂': '⿺ 辶 ⿱ 丷 豕 ',
#  '㧁': '⿸ 户 ⿱ 土 厶 ',
#  '扖': '⿰ 扌 入 ',
#  '㱱': '⿰ 歹 鬼 ',
#  '腚': '⿰ 月 ⿱ 宀 ⿱ 一 龰 ',
#  '瀲': '⿰ 氵 ⿰ ⿳ ⿱ 人 一 ⿰ 口 口 ⿰ 人 人 攵 ',
#  '㿺': '⿰ ⿱ 日 ⿱ ⿱ 龷 八 氺 皮 ',
#  '賐': '⿰ ⿱ 目 八 ⿳ 厶 八 夂 ',
#  '㚚': '⿱ 大 ⿱ 夕 口 ',
#  '㟢': '⿱ 山 ⿱ 大 ⿹ 丁 口 ',
#  '鐽': '⿰ 金 ⿺ 辶 ⿱ 土 羊 ',
#  '刵': '⿰ 耳 刂 ',
#  '䗗': '⿰ 虫 ⿱ 竹 ⿱ 一 廾 ',
#  '瑉': '⿰ 王 ⿱ 民 日 ',
#  '㿊': '⿸ 疒 ⿱ ⿰ 旡 旡 日 ',
#  '傃': '⿰ 亻 ⿱ 龶 糸 ',
#  '䤦': '⿰ 金 ⿰ 亻 戈 ',
#  '嗑': '⿰ 口 ⿱ ⿱ 土 厶 皿 ',
#  '鏭': '⿰ 金 ⿱ 釆 心 ',
#  '痓': '⿸ 疒 ⿱ ⿱ 一 厶 土 ',
#  '燆': '⿰ 火 ⿱ ⿱ ⿱ 丿 大 口 ⿵ 冂 口 ',
#  '㴳': '⿲ 氵 土 ⿷ ⿺ 尢 丶 彡 ',
#  '㬛': '⿰ 日 ⿱ ⿱ ⿱ 人 一 口 ⿰ 习 习 ',
#  '惩': '⿱ ⿰ 彳 ⿱ 一 止 心 ',
#  '䩫': '⿰ 革 ⿱ 一 ⿻ 巾 ⿰ 入 入 ',
#  '邈': '⿺ 辶 ⿰ 豸 ⿱ 白 儿 ',
#  '榓': '⿰ 木 ⿱ 必 皿 ',
#  '㴬': '⿰ 氵 ⿰ 身 寸 ',
#  '眼': '⿰ 目 艮 ',
#  '夻': '⿱ 大 口 ',
#  '䣓': '⿰ ⿳ 一 口 ⿵ ⿵ 冂 儿 ⿱ 一 丨 阝 ',
#  '㖤': '⿰ 口 ⿶ 凵 ⿻ 了 ⿱ 丷 八 ',
#  '㚂': '⿰ 土 ⿳ ⿻ 一 中 冖 ⿱ ⿱ ⿰ 口 口 ⿱ 井 一 𧘇 ',
#  '猋': '⿱ 犬 ⿰ 犬 犬 ',
#  '佣': '⿰ 亻 ⿵ 冂 ⿻ 二 丨 ',
#  '荓': '⿱ 艹 ⿱ 丷 ⿱ 一 廾 ',
#  '㕷': '⿰ 口 白 ',
#  '雼': '⿱ 雨 石 ',
#  '嬬': '⿰ 女 ⿱ 雨 而 ',
#  '绗': '⿰ 纟 ⿰ 彳 ⿱ 一 丁 ',
#  '䙽': '⿱ ⿻ 大 丷 ⿱ 目 儿 ',
#  '砻': '⿱ 龙 石 ',
#  '莨': '⿱ 艹 ⿱ 丶 艮 ',
#  '蹺': '⿰ ⿱ 口 止 ⿱ ⿱ 土 ⿰ 土 土 兀 ',
#  '罂': '⿱ ⿰ 贝 贝 缶 ',
#  '㝿': '⿺ 尢 皮 ',
#  '㓱': '⿰ ⿱ ⿱ 人 一 ⿰ 月 刂 刂 ',
#  '抱': '⿰ 扌 ⿹ 勹 巳 ',
#  '裧': '⿰ 衤 ⿱ 火 火 ',
#  ...}

# %%
label_target = list(radical_dict.keys())[0]

# %%
label_target
# Out:
# '说'

# %%
radical_dict[label_target]
# Out:
# '⿰ 讠 ⿱ 丷 ⿱ 口 儿 '

# %%
lexicon_target = radical_dict[label_target]
lexicon_target_list_old = lexicon_target.split()
lexicon_target_list = []
for i in lexicon_target_list_old:
    if i not in space_list:
        lexicon_target_list.append(i)
lexicon_target = ' '.join(lexicon_target_list)

# %%
lexicon_target_list_old
# Out:
# ['⿰', '讠', '⿱', '丷', '⿱', '口', '儿']

# %%
lexicon_target_list
# Out:
# ['讠', '丷', '口', '儿']

# %%
lexicon_target
# Out:
# '讠 丷 口 儿'

# %%
corpus = open("original_data/seen_char.txt", "r").read().splitlines()

# %%
corpus
# Out:
# ['scenary',
#  'pterygopalatal',
#  'restructure',
#  'Arkansaw',
#  'actionize',
#  'nondenseness',
#  'exhumate',
#  'plasmogen',
#  'subtractor',
#  'Todd',
#  'chinkle',
#  'belabor',
#  'semi-opal',
#  'Buckley',
#  'alumin',
#  'megakaryocyte',
#  'prospecting',
#  'utfangenethef',
#  'worldish',
#  'Mike',
#  "law's",
#  'tallywag',
#  'shellack',
#  'antiritualistic',
#  'glass-house',
#  'endocrinopathy',
#  'underkingdom',
#  'enteroplasty',
#  'ribandry',
#  'Technion',
#  'abscessed',
#  'fictionalizes',
#  'bulbous',
#  'drug-grinding',
#  'tautozonality',
#  'checker-roll',
#  'pseudo-Muslim',
#  'arriccio',
#  'pandits',
#  'DASWDT',
#  'dehydrogenise',
#  'lipins',
#  'Augier',
#  'smugglery',
#  'acro-',
#  'ladyless',
#  'guidman',
#  'megalopore',
#  'plain-dressing',
#  'Peritricha',
#  'carburate',
#  'Groot',
#  'rearer',
#  'Casanovanic',
#  'monkbird',
#  'fabes',
#  'euodic',
#  'unspecific',
#  'sodiotartrate',
#  'trucked',
#  'decemflorous',
#  'leaf-forming',
#  'ebonizing',
#  'jurament',
#  'varicosities',
#  'polynucleate',
#  'carioles',
#  'compress',
#  'mucedine',
#  'Oleg',
#  'rittingerite',
#  'ballades',
#  'noncontemporaneously',
#  'choosier',
#  'tangent-sawing',
#  'twice-anticipated',
#  'world-favored',
#  'notacanthoid',
#  'headline',
#  'multisensory',
#  'periwigged',
#  'mutenesses',
#  'Aldarcie',
#  'domesticality',
#  'Heptanchus',
#  'bill-and-cooers',
#  'scaup',
#  'goosefoots',
#  'airworthiest',
#  'myristin',
#  'many-faceted',
#  'alulae',
#  'nonintroversive',
#  'Odebolt',
#  'marcottage',
#  'obstreperous',
#  'Pseudo-isidorian',
#  'Tichon',
#  'Harness',
#  'ethnolinguistics',
#  'Portobello',
#  'ventroaxillary',
#  'squarishly',
#  'nonserous',
#  'repertorily',
#  'kor',
#  'hyzone',
#  'grudger',
#  'reenter',
#  'Morrison',
#  'Podura',
#  'indazol',
#  'babirusa',
#  'behead',
#  'Bushkill',
#  'enterokinesia',
#  'Deleon',
#  'harrumphs',
#  'shovelfuls',
#  'subsisted',
#  'galleries',
#  'Mazurian',
#  'proterothesis',
#  'hootch',
#  'catenaries',
#  'critize',
#  'outroad',
#  'frigate-built',
#  'Amaras',
#  'beperiwigged',
#  'metavanadate',
#  'vexedly',
#  'hedgepig',
#  'socmanry',
#  'seromembranous',
#  'weftwize',
#  'beefy',
#  'chairmaning',
#  'girrit',
#  'heal-dog',
#  'intra-mercurial',
#  'machinate',
#  'mobilise',
#  'unsober',
#  'ticket-selling',
#  'whitecoat',
#  'specsartine',
#  'subduple',
#  'beclamoring',
#  'eiresione',
#  'uxoriousness',
#  'programmata',
#  'Poteet',
#  'nonresolvable',
#  'Schargel',
#  'Celastraceae',
#  'maumetry',
#  'bronchotetany',
#  'schoolmaster',
#  'pricemaker',
#  'teratogeny',
#  'unrespectiveness',
#  'Bront',
#  'Pantia',
#  'Lilly',
#  'acetylate',
#  'crampit',
#  'unseamanlike',
#  'desalinized',
#  'chlorosis',
#  'disniche',
#  'oversow',
#  'myriad-leaf',
#  'valancing',
#  'matzos',
#  'Bail',
#  'anterooms',
#  'battologizing',
#  'exodos',
#  'housemates',
#  'inferiorize',
#  'earshell',
#  'pothole',
#  'maitre',
#  'Acmaea',
#  'corrump',
#  'gerip',
#  'coeditorship',
#  'flower-de-luce',
#  'Apollinaire',
#  'persico',
#  'swungen',
#  'fall-sow',
#  'indianite',
#  'shorling',
#  'dissatisfactoriness',
#  'Amazonis',
#  'Panagias',
#  'crosscut',
#  'Vincents',
#  'bloody-nosed',
#  'commensurable',
#  'disputeless',
#  'antennifer',
#  'overmonopolize',
#  'reeper',
#  'devel',
#  'fetuses',
#  'rummaging',
#  'traditionary',
#  'ankyloproctia',
#  'melammdim',
#  'nongays',
#  'Trichilia',
#  'megatron',
#  'jugglement',
#  'overdecks',
#  'nonexamination',
#  'subbrigadier',
#  'submuscularly',
#  'Grignolino',
#  'overtenacious',
#  'concentrate',
#  'attendant',
#  'CLEF',
#  'jetport',
#  'cambered',
#  'farrier',
#  'QA',
#  'fertilize',
#  'spaced',
#  'sepaloid',
#  'Zarathustrism',
#  'blue-stained',
#  'macroaggregated',
#  'unpiteously',
#  'yellowtail',
#  'cohosts',
#  'tlaco',
#  'oulap',
#  'droitsman',
#  'ex-emperor',
#  'Babylonite',
#  'thiefdom',
#  'Nunn',
#  'dhow',
#  'presupreme',
#  'disseminator',
#  'cultureless',
#  'Rumpf',
#  'dissertative',
#  'Spanish-American',
#  'asunder',
#  'vulgare',
#  'entocranial',
#  'brazen-faced',
#  'chilodon',
#  'apostrophizing',
#  'unsocialised',
#  'Barbaresi',
#  'evenlong',
#  'slate',
#  'disconsolacy',
#  'floatation',
#  'brandenburgs',
#  'clethrionomys',
#  'Coco',
#  'tiniest',
#  'atonality',
#  'sporadicalness',
#  'ceruminous',
#  'pre-enable',
#  'equationally',
#  'blowers',
#  'Stavro',
#  'mustardy',
#  'slap-bang',
#  'stood',
#  'amban',
#  'javanine',
#  'rattening',
#  'outproducing',
#  'demonstration',
#  'pharynxes',
#  'unlicentiousness',
#  "ventricle's",
#  'subhooked',
#  'pleurodynic',
#  'procaines',
#  'Audun',
#  'pleurorrhea',
#  'hematopathology',
#  'idolomania',
#  'Jeremias',
#  're-edificate',
#  'inventiveness',
#  'non-access',
#  'cablish',
#  'Muir',
#  'canc.',
#  'heteroinoculation',
#  'assizement',
#  'Colyer',
#  'well-ringed',
#  'amyelic',
#  'laryngoscopically',
#  'medium-rare',
#  'pengos',
#  'thy',
#  'parentheses',
#  'subnect',
#  'satyrlike',
#  'yellow-fleeced',
#  'emptyhearted',
#  'definitions',
#  'yerva',
#  'metacircular',
#  'Konya',
#  'muzzle',
#  'sturk',
#  'liquorice',
#  'quarterdeckish',
#  'backdates',
#  'superexistent',
#  'addressed',
#  'pyrotoxin',
#  'unvisiting',
#  'ridge-seeded',
#  'optimizers',
#  'chumpa',
#  'fadlike',
#  'electrotonicity',
#  'misspeaking',
#  'puller-in',
#  'Mabuse',
#  'planetesimal',
#  'shallopy',
#  'titleless',
#  'interbranch',
#  'slidableness',
#  'wrnt',
#  'frizzy',
#  'cytococcus',
#  'dirten',
#  'soapstone',
#  'blown-molded',
#  'levator',
#  'choreutic',
#  'intros',
#  'rashers',
#  'efficacies',
#  'luteotropic',
#  'Ridgeview',
#  'gemots',
#  "spot's",
#  'Lactuca',
#  'cacotrophia',
#  'buccolingual',
#  'fempty',
#  'excubitorium',
#  'Edholm',
#  'unendurability',
#  'tires',
#  'VLA',
#  'kronen',
#  'twittle',
#  'antinationalistically',
#  'Chromobacterium',
#  'rightists',
#  'fiendishness',
#  'leptomatic',
#  'synusiast',
#  'proportionment',
#  'Gannon',
#  'Keli',
#  'hemase',
#  'sequential',
#  'sociolegal',
#  'unct',
#  'arcs-boutants',
#  'embulk',
#  'allodial',
#  'epencephalon',
#  'Bharat',
#  'Lonestar',
#  'oligopsony',
#  'smoothen',
#  'buckboard',
#  'NbW',
#  'hip-gout',
#  'orcs',
#  'beckons',
#  'twice-ruined',
#  'resistence',
#  'Dorcus',
#  'kremlins',
#  'semioxygenized',
#  'smartens',
#  'thirty-day',
#  'zeekoe',
#  'Zootoca',
#  'upright-minded',
#  'Yukon',
#  'micropin',
#  'misdescribing',
#  'abuzz',
#  'villiaumite',
#  'fecula',
#  'grandpa',
#  'scribophilous',
#  'self-defense',
#  'gingivitis',
#  'severe',
#  'accresce',
#  'whole-spirited',
#  'olibanum',
#  'Maryrose',
#  'palaeozoologic',
#  'quislings',
#  'subsisting',
#  'Goessel',
#  'noninflammability',
#  'uneye',
#  'underload',
#  'dullishly',
#  'Laelaps',
#  'pleasureproof',
#  'uneffeteness',
#  'preallocates',
#  'holograms',
#  'uprighteousness',
#  'milkstone',
#  'repeller',
#  'mandiocas',
#  'pickpockets',
#  'colopexy',
#  'Nilwood',
#  'spatha',
#  'unmustered',
#  'vistlik',
#  'experimentarian',
#  'lupine',
#  'preknowing',
#  'breastfeeding',
#  'metavauxite',
#  'Patmo',
#  'uncravingly',
#  'angiospermic',
#  'ombrifuge',
#  'Nivose',
#  'Silvana',
#  "devil's",
#  'Barocius',
#  'Consalve',
#  'ten-second',
#  'Gelett',
#  'lactam',
#  'hexakistetrahedron',
#  'declassing',
#  'needle-form',
#  'chromonemata',
#  'gynaecic',
#  'punction',
#  'Isadore',
#  'color-matching',
#  'crisped-leaved',
#  'dewool',
#  'octachronous',
#  'Randy',
#  'Chlorella',
#  'highbush',
#  'incurrence',
#  'Sonrai',
#  'foremilk',
#  'bamboos',
#  'physiologue',
#  'monotrochian',
#  'diabolonian',
#  'vesiculate',
#  'alphanumerics',
#  'thought-haunted',
#  'baldachin',
#  'eulytin',
#  'undiamonded',
#  'outdoorsmen',
#  'nonaxiomatically',
#  'legalness',
#  'Lynnett',
#  'nixed',
#  'world-crushed',
#  'fugu',
#  'applegrower',
#  'Minotaur',
#  'spongiosity',
#  'unattentive',
#  'ill-kept',
#  'annunciative',
#  'unprudentially',
#  'Waylin',
#  'Delawarean',
#  'gastrohysteropexy',
#  'DDE',
#  'issuers',
#  'Werchowinci',
#  'caravaning',
#  'Hiroshima',
#  "girl's",
#  'submucous',
#  'altitudes',
#  'butyrin',
#  'farmed',
#  'overswelled',
#  'preblockading',
#  'agoing',
#  'superaffiliation',
#  'square-tailed',
#  'Gloster',
#  'skunklet',
#  'poncelet',
#  'myoliposmias',
#  'well-remarked',
#  'spitfire',
#  'kamperite',
#  'unlogistic',
#  'forty-seven',
#  'Jenelle',
#  'postless',
#  'Tappertitian',
#  'telepathies',
#  'Zelos',
#  'lalled',
#  "hand's-breadth",
#  'choriocapillary',
#  'crepine',
#  'metaloscopy',
#  'zizz',
#  'hardsalt',
#  'cheeper',
#  'artistical',
#  'poseur',
#  'monometallism',
#  'Starkweather',
#  'Hyphaene',
#  'panmnesia',
#  'nonperceptive',
#  'fatbird',
#  'Lohman',
#  'Un-platonically',
#  'McNalley',
#  'nebbish',
#  'preexemption',
#  'regular-sized',
#  'unsedulous',
#  're-export',
#  'dockworkers',
#  'undergraduate',
#  'addicent',
#  'anagyrin',
#  'homeomorph',
#  'anabaptists',
#  'Skagen',
#  'unkindly',
#  'brachycephales',
#  'Phaenogamia',
#  'Tomopteris',
#  "what're",
#  'kolobia',
#  'terbiums',
#  'extravagant',
#  'Geller',
#  'imperviable',
#  'fusibly',
#  'misesteemed',
#  'Rocco',
#  'Formicivora',
#  'teiglech',
#  "crux's",
#  'pipes',
#  'retheness',
#  'Aleurodidae',
#  'diamond-producing',
#  'well-perfected',
#  'goose-neck',
#  'spondylioid',
#  'Licetus',
#  'dodipole',
#  'ADN',
#  'portiomollis',
#  'Maxey',
#  'alture',
#  'unpained',
#  'impunctate',
#  'factfinder',
#  'Dadupanthi',
#  'irks',
#  'single-mouthed',
#  'hierogram',
#  'unhealthfully',
#  'obturation',
#  'polynucleated',
#  'sulphoxism',
#  'motorphobe',
#  'blackwasher',
#  'mesovarium',
#  'linneon',
#  'noncondescendingly',
#  'delict',
#  'prophetship',
#  'distinguish',
#  'dowered',
#  'ewelease',
#  'Winterville',
#  'subservience',
#  'culerage',
#  'ill-shaped',
#  'wuzzling',
#  'Catocala',
#  'fair-browed',
#  'uncontemporaneously',
#  'init.',
#  'palaeostriatal',
#  'relative',
#  'sulphoxyphosphate',
#  'nonmischievous',
#  'replicon',
#  'midline',
#  'reinstalling',
#  'avadana',
#  'dipygus',
#  'owlhead',
#  'duodenojejunostomies',
#  'preequipment',
#  'propinoic',
#  'strutters',
#  'superopposition',
#  'gunnysacks',
#  'rope-muscled',
#  'relessa',
#  'fulltime',
#  'fordless',
#  'spiraculiferous',
#  'Perpetua',
#  'inofficiosity',
#  'zebrafishes',
#  'Antlia',
#  'computatively',
#  'flagrantly',
#  'goblinism',
#  'overfalling',
#  'yocks',
#  'endangitis',
#  'rumbustious',
#  'chria',
#  'monoculus',
#  'irregenerate',
#  'typhotoxine',
#  'amhar',
#  'outbanter',
#  'over-age',
#  'Zen',
#  'feminizing',
#  'Balkanise',
#  'preimage',
#  'Bordelonville',
#  'stoichiometrically',
#  'Lampasas',
#  'Jivaro',
#  'noninitially',
#  'motortrucks',
#  'temporalness',
#  'Stanislaus',
#  'triggerless',
#  'arrogantness',
#  'undercircling',
#  'Borer',
#  'securitan',
#  'ice-imprisoned',
#  'Isar',
#  'Marxianism',
#  'tholance',
#  'Fithian',
#  'tympanism',
#  'pneumonoconiosis',
#  'Wanfried',
#  'Fens',
#  'enroots',
#  'whirled',
#  'shaksheer',
#  'mouill',
#  'metronym',
#  'proteanwise',
#  'incandesced',
#  'Bergman',
#  'sparkplugged',
#  'anchovy',
#  'wrists',
#  'compted',
#  'sceptics',
#  'Quigley',
#  'Tengler',
#  'pulpitish',
#  'slantindicularly',
#  'pediculine',
#  'dermatomyoma',
#  'preembarrass',
#  'spousy',
#  'anchoritism',
#  'checkle',
#  'hybosis',
#  'unthoughtlike',
#  'bailable',
#  'pronounce',
#  'Smicksburg',
#  'Heymaey',
#  'grass-roofed',
#  'restorable',
#  'prokaryote',
#  'Takhaar',
#  'Master',
#  'ahamkara',
#  'Ethyl',
#  'bougie',
#  'rabbit-faced',
#  'enroller',
#  'snaste',
#  'Machiasport',
#  'nonannihilability',
#  'continuos',
#  'epistases',
#  'faultiness',
#  'appliqued',
#  'aurists',
#  'supersensual',
#  'Jonesville',
#  'toxicognath',
#  'cerebromeningeal',
#  'Eurybia',
#  'multisegmented',
#  'wildness',
#  'brinier',
#  'hordeiform',
#  'brucin',
#  'periproctitis',
#  'Rasenna',
#  'groo-groo',
#  'transuded',
#  'breakerman',
#  'dispeller',
#  'faldworth',
#  'nonlustrous',
#  'reproductive',
#  'tailplane',
#  'chambrel',
#  'embellisher',
#  'chunder',
#  'primatic',
#  'breeks',
#  'reflexives',
#  'Pro-guianan',
#  'aortomalaxis',
#  'copublishing',
#  'Pergamon',
#  'usherdom',
#  'nonretrenchment',
#  'disapprover',
#  'Anseres',
#  'autobolide',
#  'spiritoso',
#  'accuses',
#  'roughs',
#  'woopsing',
#  'gymnogenous',
#  'bloodfin',
#  'bdellid',
#  'Ula',
#  'enlighten',
#  'overiodized',
#  'MLD',
#  'Ashlie',
#  'mysticizing',
#  'chloropsia',
#  'NPG',
#  'entertainer',
#  'puboiliac',
#  'caned',
#  'uncounsellable',
#  'recurvo-',
#  'gingerwort',
#  'officiate',
#  'stridently',
#  'monochromist',
#  'brachelytrous',
#  'cangues',
#  'wharp',
#  'all-shunned',
#  'Amblypoda',
#  'headlock',
#  'japygid',
#  'hypercoagulability',
#  'cherogril',
#  'nonabrasive',
#  'anticonscriptive',
#  'brinkless',
#  'emollient',
#  'notice',
#  'Chickahominy',
#  'officina',
#  'stadia',
#  'ensuable',
#  'sun-ray',
#  'dinnerless',
#  'Judaize',
#  'alveolate',
#  'Kuebbing',
#  'FSCM',
#  'pedante',
#  'elevating',
#  'heirships',
#  'test-ban',
#  'leptocercal',
#  'Ibibio',
#  'conservatrix',
#  'ataunt',
#  'Lophophorus',
#  'silaginoid',
#  'orthotone',
#  'schoolbooks',
#  'reelected',
#  'furnacer',
#  'phytogeographic',
#  'Moriches',
#  'griffinesque',
#  'eavesdrip',
#  'twice-beheld',
#  'Liguorian',
#  'yecchs',
#  'Thwing',
#  'assonantly',
#  'verrucosity',
#  'Hockley',
#  'Thorrlow',
#  'chiefish',
#  'cheeter',
#  'USG',
#  'Tartarean',
#  'decd.',
#  'death-worthy',
#  'retardive',
#  'tressilate',
#  'undersaw',
#  'deteriorating',
#  'one-striper',
#  'filesmith',
#  'pseudobulbil',
#  'coeliotomy',
#  'misalphabetize',
#  'paramedian',
#  'pick-bearing',
#  'passengers',
#  'Cellepora',
#  'botong',
#  'clownade',
#  'ereptase',
#  'scolecoid',
#  'statutum',
#  'miniaturized',
#  'bookworms',
#  'curarines',
#  'resiliate',
#  'yill-caup',
#  'echoencephalography',
#  'dog-fennel',
#  'Eogaean',
#  'shauls',
#  'unforeknowable',
#  'pandure',
#  'raceline',
#  'ungrained',
#  'cerebrotonic',
#  'picudo',
#  'facia',
#  'bespreng',
#  'vulnific',
#  'epiotic',
#  'affixt',
#  'dealerdom',
#  'Eileen',
#  'stengahs',
#  'aworth',
#  'mesoplastra',
#  'peaklike',
#  'ultramarine',
#  'vellosine',
#  'Mariya',
#  'disappear',
#  'warpage',
#  'pansies',
#  'miter',
#  'aur-',
#  'Quintus',
#  'enteroceptor',
#  'bergomask',
#  're-expectation',
#  'wod',
#  'Podolian',
#  'shelducks',
#  'interpolater',
#  'Abinger',
#  'calvadoses',
#  'commulative',
#  'ridleys',
#  'uncarolled',
#  'desolateness',
#  'Bertolt',
#  'Algerine',
#  'one-hearted',
#  'Mide',
#  'backswordmen',
#  'Obad',
#  'Priapulidae',
#  'Thanatotic',
#  'hitherward',
#  'Populist',
#  'bubonalgia',
#  'Safire',
#  'irrefutability',
#  'ferrovanadium',
#  'reacquiring',
#  'buttes',
#  'honor-giving',
#  'Menotyphla',
#  'jonglem',
#  'phrasy',
#  'yellow-splotched',
#  'Lowes',
#  'hostel',
#  'notopodium',
#  'superorganism',
#  'clockhouse',
#  'ironheartedly',
#  'puntist',
#  'Balkanism',
#  'monkmonger',
#  'SRB',
#  'unrivalled',
#  'appointments',
#  'knapsacked',
#  'SIR',
#  'carping',
#  'catenated',
#  'cheerled',
#  'eriocaulaceous',
#  'squencher',
#  'touchback',
#  'phat',
#  'offcast',
#  'pigmaker',
#  'red-flagger',
#  'myelosyringosis',
#  'bedewoman',
#  'curiality',
#  'rashnesses',
#  'Eshkol',
#  'arecaceous',
#  'Sadler',
#  'spuries',
#  'explainable',
#  'tumble',
#  'oogametes',
#  'cockatrice',
#  'binnite',
#  'catarrhous',
#  'Luebke',
#  'coloenteritis',
#  'panaceas',
#  'unubiquitous',
#  'Faizabad',
#  'bevies',
#  'pseudoethically',
#  'Lobel',
#  'tambor',
#  'cinctures',
#  'overcommand',
#  'retirers',
#  'porpoises',
#  'disconformity',
#  'turpethin',
#  'bobachee',
#  'lacquers',
#  'Hulda',
#  'knife-stripped',
#  'tuboovarial',
#  'psychoanalyzes',
#  'puttyroot',
#  'twice-specified',
#  'short-cycled',
#  'archaicness',
#  'lamplet',
#  'fluxweed',
#  'limiters',
#  ...]
