# %%
import os
from PIL import Image

# %%
fd = "/home/jupyter/ai_font/data/reports/exp0514/van_fontdiffuser"

# %%
files = sorted([f"{fd}/{f}" for f in os.listdir(fd)])

# %%
len(files)
# Out:
# 3936

# %%
Image.open(f"{fd}/{files[20]}")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=96x96>

# %%
files
# Out:
# ['van_fontdif__트와이스 채영__낯.png',
#  'van_fontdif__트와이스 지효__겸.png',
#  'van_fontdif__트와이스 지효__궪.png',
#  'van_fontdif__트와이스 채영__괻.png',
#  'van_fontdif__트와이스 채영__닒.png',
#  'van_fontdif__트와이스 채영__긙.png',
#  'van_fontdif__플레이브 밤비__흺.png',
#  'van_fontdif__플레이브 밤비__혾.png',
#  'van_fontdif__트와이스 지효__궢.png',
#  'van_fontdif__트와이스 지효__겨.png',
#  'van_fontdif__플레이브 밤비__흗.png',
#  'van_fontdif__트와이스 채영__낔.png',
#  'van_fontdif__트와이스 채영__댶.png',
#  'van_fontdif__트와이스 지효__건.png',
#  'van_fontdif__플레이브 밤비__혶.png',
#  'van_fontdif__트와이스 채영__꼕.png',
#  'van_fontdif__트와이스 채영__계.png',
#  'van_fontdif__트와이스 지효__괲.png',
#  'van_fontdif__트와이스 채영__돽.png',
#  'van_fontdif__플레이브 밤비__혈.png',
#  'van_fontdif__플레이브 밤비__훻.png',
#  'van_fontdif__트와이스 채영__눫.png',
#  'van_fontdif__트와이스 채영__곽.png',
#  'van_fontdif__트와이스 지효__긩.png',
#  'van_fontdif__트와이스 채영__뇆.png',
#  'van_fontdif__트와이스 지효__굴.png',
#  'van_fontdif__트와이스 채영__뒶.png',
#  'van_fontdif__트와이스 지효__굡.png',
#  'van_fontdif__트와이스 지효__겍.png',
# ...
