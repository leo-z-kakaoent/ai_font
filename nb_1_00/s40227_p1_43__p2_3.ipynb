# %%
import os
import sys
import numpy as np
from tqdm import tqdm
from PIL import Image
from font_diffuser.args import SampleArgs
from font_diffuser.sample import load_fontdiffuer_pipeline, sampling

class ImageConcat:
    def __init__(self, n_h, n_v, resolution=96):
        self.n_h = n_h
        self.n_v = n_v
        self.r = resolution
        self.img = Image.new("RGB", (self.n_h*self.r, self.n_v*self.r))
        self.cursor = [0,0]
        
    def move_cursor_h(self):
        self.cursor[0] += self.r
        
    def move_cursor_v(self):
        self.cursor[1] += self.r
        
    def reset_cursor_h(self):
        self.cursor[0] = 0
        
    def append_img(self, im):
        self.img.paste(im, tuple(self.cursor))
        
    def save_img(self, path):
        self.img.save(path)

        
class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

        
def black2blue(img):
    array_img = np.array(img)
    for i in range(96):
        for j in range(96):
            if not np.all(array_img[i,j,:] > 200):
                array_img[i,j,:] = (0,0,140)
    return Image.fromarray(array_img)

def black2gray(img):
    array_img = np.array(out_image, dtype=np.float32)
    array_img = array_img - 255
    array_img = array_img * 0.75
    array_img = array_img + 255
    return Image.fromarray(array_img.astype(np.uint8))
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
args = SampleArgs()
r = 96
n_h = 6
n_v = 12
contents = np.arange(0,11172,11172/(n_h*n_v), dtype=int)

# %%
pipe = load_fontdiffuer_pipeline(args=args,model_i="p2_30000")
pbar = tqdm([p.split(".ttf")[0] for p in os.listdir("data/r40202/ttfs") if ("UhBee" in p) or ("twice" in p)])
for style in pbar:
    style_image_paths = [p for p in os.listdir("data/r40202/pngs/") if style in p]
    if ("p1_43__p2_3__%s.png"%style not in os.listdir("data/f40305/"))&(len(style_image_paths)>0):
        with HiddenPrints():
            bigimg = ImageConcat(n_h=n_h*2, n_v=n_v, resolution=r)
            style_image = Image.open("data/r40202/pngs/"+style_image_paths[0]).convert('RGB')
            c = 0
            for _ in range(n_v):
                for _ in range(n_h):
                    ci = contents[c]
                    content_image = Image.open("data/r40202/pngs/gulim__%s.png"%str(ci)).convert('RGB')
                    try:
                        bigimg.append_img(Image.open("data/r40202/pngs/%s__%s.png"%(str(style), str(ci))).convert('RGB'))
                    except:
                        bigimg.append_img(Image.open("data/f40219/noimg.png").convert('RGB'))
                    bigimg.move_cursor_h()

                    out_image = sampling(
                            args=args, 
                            pipe=pipe, 
                            content_image=content_image,
                            style_image=style_image,
                        )
                    bigimg.append_img(black2gray(out_image))
                    bigimg.move_cursor_h()

                    c += 1
                bigimg.reset_cursor_h()
                bigimg.move_cursor_v()
            bigimg.save_img("data/f40305/p1_43__p2_3__%s.png"%style)
            pbar.set_postfix(style=style)
# Out:
# Load the down block  DownBlock2D
# Load the down block  MCADownBlock2D
# The style_attention cross attention dim in Down Block 1 layer is 1024
# The style_attention cross attention dim in Down Block 2 layer is 1024
# Load the down block  MCADownBlock2D
# The style_attention cross attention dim in Down Block 1 layer is 1024
# The style_attention cross attention dim in Down Block 2 layer is 1024
# Load the down block  DownBlock2D
# Load the up block  UpBlock2D
# Load the up block  StyleRSIUpBlock2D
# Load the up block  StyleRSIUpBlock2D
# Load the up block  UpBlock2D
# Param count for Ds initialized parameters: 20591296
# Get CG-GAN Style Encoder!
# Param count for Ds initialized parameters: 1187008
# Get CG-GAN Content Encoder!
# Loaded the model state_dict successfully!
# Loaded training DDPM scheduler sucessfully!
# Loaded dpm_solver pipeline sucessfully!
#   0%|          | 0/170 [00:00<?, ?it/s]/home/jupyter/ai_font/font_diffuser/model.py:88: FutureWarning: Accessing config attribute `style_encoder` directly via 'FontDiffuserModelDPM' object attribute is deprecated. Please access 'style_encoder' over 'FontDiffuserModelDPM's config object instead, e.g. 'unet.config.style_encoder'.
#   style_img_feature, _, style_residual_features = self.style_encoder(style_images)
# /home/jupyter/ai_font/font_diffuser/model.py:94: FutureWarning: Accessing config attribute `content_encoder` directly via 'FontDiffuserModelDPM' object attribute is deprecated. Please access 'content_encoder' over 'FontDiffuserModelDPM's config object instead, e.g. 'unet.config.content_encoder'.
#   content_img_feture, content_residual_features = self.content_encoder(content_images)
# /home/jupyter/ai_font/font_diffuser/model.py:97: FutureWarning: Accessing config attribute `content_encoder` directly via 'FontDiffuserModelDPM' object attribute is deprecated. Please access 'content_encoder' over 'FontDiffuserModelDPM's config object instead, e.g. 'unet.config.content_encoder'.
#   style_content_feature, style_content_res_features = self.content_encoder(style_images)
# /home/jupyter/ai_font/font_diffuser/model.py:102: FutureWarning: Accessing config attribute `unet` directly via 'FontDiffuserModelDPM' object attribute is deprecated. Please access 'unet' over 'FontDiffuserModelDPM's config object instead, e.g. 'unet.config.unet'.
#   out = self.unet(
# 100%|██████████| 170/170 [6:35:46<00:00, 139.68s/it, style=UhBee Tokki Bold]

# %%
import zipfile
import os

fd = "data/f40305/"
file_list = [fd+f for f in os.listdir(fd)]
with zipfile.ZipFile('sample_all.zip', 'w') as myzip_all:
    for f in file_list:
        myzip_all.write(f)
        print(f, 'is written to myzip_all.zip')
    myzip_all.close()
# Out:
# data/f40305/p1_43__p2_3__UhBee puding Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee U JEONG.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee puding.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee KOR.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Ham.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Sunhong.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee KeongKeong.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Miwan Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee BongSik BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee chae-eun.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Namjieun.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee MiMi.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Soyun.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Banynany Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee hye mong Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee+Jaeyoun+Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jin-gun Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yehee Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jin-gun.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ARyong Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee song.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Gmin2 Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Han HUEY Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Minidori.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Yiseul Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee mingi calli.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ZIGLE Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee wocked woman.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice mina_4.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Gmin2.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yoongdi.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee LovelyAN Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Hyundyu Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ddolyoung BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jisyuk jisyuk BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee UJong.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee JJIBBABBA.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee mysen Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Kairu BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Han HUEY.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Mardyu.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBeeZZIBA-Regular.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee RingRing Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ann Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Hanbee Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Tokki.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yehee.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee matsuko.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ibuson.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Strawberry.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee JJIBBABBA Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee DDOYO.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee EUN KYUNG Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yul.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Wooyakeboong.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee MiMi Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Skyrain.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Mardyu Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee+Jaeyoun.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yul Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee YanNeu.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ARyong.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Ryuga Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice tzuyu_4.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee namsoyoung.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee dami.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee YanNeu Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Hyeki.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee charming Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee wocked woman Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee song Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee namsoyoung Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee chae-eun Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Miwan.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee MinAhBang Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee GGoongD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jjipungding Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice momo_6.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yoonjaa Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Hyundyu.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee jung BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Simple girl BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee KeongKeong Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee BEOJJI Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee UZ Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee eunD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Se_hyun.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee swit.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ddolyoung.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee UZ.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Yiseul.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee eunD Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Motomi.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Sunhong BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Kang-Ja.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Kang-Ja Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee baby.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee UJong Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee QUEEN J.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee TOMO.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Ryuga.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee DongKyung BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee HanByeol.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee U JEONG Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Tokki Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Hyeki Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ZIGLE.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee mingi calli Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee DoolDool Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee mun seul ye.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Rami BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee DongKyung.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice dahyun_4.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee mun seul ye Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Skyrain BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Rice.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Rami.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee W yum.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee W yum Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee mysen.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jjipungding.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee RingRing.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee baby Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Simple girl.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee HYUNJUNG.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee dami Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Joker.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee EUN KYUNG.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Hanbee.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Howl.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee BEOJJI.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee My Husband Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice jeongyeon_4.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jisyuk jisyuk.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee HYUNJUNG Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Joker Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee freak researcher minani.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yoongdi Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Banynany.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Strawberry BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee jung.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee ann.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee MinAhBang.png is written to myzip_all.zip
# data/f40305/.ipynb_checkpoints is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee LovelyAN.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Namjieun Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee DoolDool.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee BongSik.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Kairu.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee charming.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee yoonjaa.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Seulvely.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Ham Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee GEN WOO.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee My Husband.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee hye mong.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee matsuko Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee DDOYO BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee HanByeol BOLD.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee GEN WOO Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice jihyo_4.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Jiyoung.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Heeyom.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Se_hyun Bold.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice nayeon_6.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__twice sana_4.png is written to myzip_all.zip
# data/f40305/p1_43__p2_3__UhBee Yeonie.png is written to myzip_all.zip
