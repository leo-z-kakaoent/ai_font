# %%
import os
import shutil
from tqdm import tqdm

path = "/home/jupyter/ai_font/data"
parts = "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎㅏㅐㅑㅒㅓㅔㅕㅖㅗㅘㅙㅚㅛㅜㅝㅞㅟㅠㅡㅢㅣㄳㄵㄶㄺㄻㄼㄽㄾㄿㅀㅄ"

# %%
for font in tqdm(os.listdir(f"{path}/train")):
    os.makedirs(f"{path}/train_parts/{font}", exist_ok=True)
    for tag in ["closing","erode","dilate"]:
        for part in parts:
            from_path = f"{path}/train/{font}/{font}__{tag}__{part}.png"
            if os.path.exists(from_path):
                shutil.move(from_path, f"{path}/train_parts/{font}/{font}__{tag}__{part}.png")
# Out:
# 100%|██████████| 422/422 [00:04<00:00, 98.79it/s]

# %%
for font in tqdm(os.listdir(f"{path}/train")):
    for f in os.listdir(f"{path}/train/{font}"):
        if f.endswith(".png"):
            letter = f.replace(".png","").split("__")[-1]
            if letter in parts:
                os.remove(f"{path}/train/{font}/{f}")
# Out:
# 100%|██████████| 422/422 [00:17<00:00, 23.54it/s]

# %%
f
# Out:
# '온글잎이빈나__dilate__껭.png'

# %%
os.listdir('/home/jupyter/ai_font/data/train/온글잎이빈나/')
# Out:
# ['온글잎이빈나__erode__떱.png',
#  '온글잎이빈나__dilate__뱌.png',
#  '온글잎이빈나__closing__샜.png',
#  '온글잎이빈나__closing__압.png',
#  '온글잎이빈나__dilate__축.png',
#  '온글잎이빈나__closing__밧.png',
#  '온글잎이빈나__dilate__뼝.png',
#  '온글잎이빈나__closing__쌨.png',
#  '온글잎이빈나__closing__쳄.png',
#  '온글잎이빈나__erode__섄.png',
#  '온글잎이빈나__closing__끓.png',
#  '온글잎이빈나__dilate__뷴.png',
#  '온글잎이빈나__closing__켕.png',
#  '온글잎이빈나__erode__틜.png',
#  '온글잎이빈나__dilate__땅.png',
#  '온글잎이빈나__dilate__슛.png',
#  '온글잎이빈나__closing__랴.png',
#  '온글잎이빈나__closing__니.png',
#  '온글잎이빈나__dilate__쭁.png',
#  '온글잎이빈나__dilate__톼.png',
#  '온글잎이빈나__closing__맞.png',
#  '온글잎이빈나__erode__룔.png',
#  '온글잎이빈나__closing__흄.png',
#  '온글잎이빈나__closing__귑.png',
#  '온글잎이빈나__erode__렉.png',
#  '온글잎이빈나__closing__낼.png',
#  '온글잎이빈나__dilate__쥘.png',
#  '온글잎이빈나__erode__네.png',
#  '온글잎이빈나__dilate__별.png',
#  '온글잎이빈나__erode__붉.png',
#  '온글잎이빈나__dilate__첨.png',
#  '온글잎이빈나__erode__틘.png',
#  '온글잎이빈나__dilate__믓.png',
#  '온글잎이빈나__dilate__휜.png',
#  '온글잎이빈나__dilate__륜.png',
# ...
