# %%
font = "플레이브밤비"

# %% [markdown]
# ## Download raw files

# %%
from google.cloud import storage
import os

def download_folder(bucket_name, source_folder_name, destination_folder_path):
    """
    Downloads a folder from a GCS bucket to a local directory.
    
    Args:
    - bucket_name (str): The name of the GCS bucket.
    - source_folder_name (str): The folder path in the GCS bucket.
    - destination_folder_path (str): The local path where the folder will be downloaded.
    """
    # Initialize the client
    client = storage.Client()

    # Get the bucket
    bucket = client.bucket(bucket_name)

    # List all blobs in the given folder
    blobs = bucket.list_blobs(prefix=source_folder_name)

    blobs = [b for b in blobs if b.name.endswith(".png")]
    for blob in blobs:a
        # Remove the folder prefix to construct the local file path
        relative_path = blob.name[len(source_folder_name):].lstrip('/')
        local_file_path = os.path.join(destination_folder_path, relative_path)

        # Ensure the local directory exists
        os.makedirs(os.path.dirname(local_file_path), exist_ok=True)

        # Download the blob to the local file
        blob.download_to_filename(local_file_path)
        print(f"Downloaded {blob.name} to {local_file_path}")

# Example usage
download_folder(
    bucket_name='leo_font',
    source_folder_name=f'raw/{font}',
    destination_folder_path=f'/home/jupyter/ai_font/data/test/raw/{font}',
)
# Out:
# Downloaded raw/플레이브밤비/갊.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/갊.png
# Downloaded raw/플레이브밤비/갸.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/갸.png
# Downloaded raw/플레이브밤비/곁.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/곁.png
# Downloaded raw/플레이브밤비/곬.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/곬.png
# Downloaded raw/플레이브밤비/교.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/교.png
# Downloaded raw/플레이브밤비/궤.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/궤.png
# Downloaded raw/플레이브밤비/껴.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/껴.png
# Downloaded raw/플레이브밤비/꽤.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/꽤.png
# Downloaded raw/플레이브밤비/꾜.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/꾜.png
# Downloaded raw/플레이브밤비/끝.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/끝.png
# Downloaded raw/플레이브밤비/높.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/높.png
# Downloaded raw/플레이브밤비/뉑.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뉑.png
# Downloaded raw/플레이브밤비/늬.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/늬.png
# Downloaded raw/플레이브밤비/닠.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/닠.png
# Downloaded raw/플레이브밤비/닦.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/닦.png
# Downloaded raw/플레이브밤비/덤.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/덤.png
# Downloaded raw/플레이브밤비/돛.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/돛.png
# Downloaded raw/플레이브밤비/돼.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/돼.png
# Downloaded raw/플레이브밤비/땍.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/땍.png
# Downloaded raw/플레이브밤비/뛰.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뛰.png
# Downloaded raw/플레이브밤비/뜻.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뜻.png
# Downloaded raw/플레이브밤비/라.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/라.png
# Downloaded raw/플레이브밤비/럽.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/럽.png
# Downloaded raw/플레이브밤비/롵.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/롵.png
# Downloaded raw/플레이브밤비/뤄.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뤄.png
# Downloaded raw/플레이브밤비/많.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/많.png
# Downloaded raw/플레이브밤비/몇.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/몇.png
# Downloaded raw/플레이브밤비/묟.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/묟.png
# Downloaded raw/플레이브밤비/무.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/무.png
# Downloaded raw/플레이브밤비/벚.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/벚.png
# Downloaded raw/플레이브밤비/붉.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/붉.png
# Downloaded raw/플레이브밤비/뷔.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뷔.png
# Downloaded raw/플레이브밤비/뺨.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뺨.png
# Downloaded raw/플레이브밤비/뽱.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/뽱.png
# Downloaded raw/플레이브밤비/쁘.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쁘.png
# Downloaded raw/플레이브밤비/삯.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/삯.png
# Downloaded raw/플레이브밤비/셴.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/셴.png
# Downloaded raw/플레이브밤비/숲.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/숲.png
# Downloaded raw/플레이브밤비/쉽.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쉽.png
# Downloaded raw/플레이브밤비/쎄.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쎄.png
# Downloaded raw/플레이브밤비/쏟.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쏟.png
# Downloaded raw/플레이브밤비/쑉.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쑉.png
# Downloaded raw/플레이브밤비/씩.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/씩.png
# Downloaded raw/플레이브밤비/얹.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/얹.png
# Downloaded raw/플레이브밤비/없.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/없.png
# Downloaded raw/플레이브밤비/왼.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/왼.png
# Downloaded raw/플레이브밤비/읊.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/읊.png
# Downloaded raw/플레이브밤비/읨.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/읨.png
# Downloaded raw/플레이브밤비/잃.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/잃.png
# Downloaded raw/플레이브밤비/쟨.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쟨.png
# Downloaded raw/플레이브밤비/점.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/점.png
# Downloaded raw/플레이브밤비/좋.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/좋.png
# Downloaded raw/플레이브밤비/줬.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/줬.png
# Downloaded raw/플레이브밤비/짚.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/짚.png
# Downloaded raw/플레이브밤비/짧.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/짧.png
# Downloaded raw/플레이브밤비/쫄.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쫄.png
# Downloaded raw/플레이브밤비/쯷.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쯷.png
# Downloaded raw/플레이브밤비/찧.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/찧.png
# Downloaded raw/플레이브밤비/찾.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/찾.png
# Downloaded raw/플레이브밤비/쳇.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쳇.png
# Downloaded raw/플레이브밤비/춰.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/춰.png
# Downloaded raw/플레이브밤비/츄.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/츄.png
# Downloaded raw/플레이브밤비/치.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/치.png
# Downloaded raw/플레이브밤비/캐.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/캐.png
# Downloaded raw/플레이브밤비/캠.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/캠.png
# Downloaded raw/플레이브밤비/쾅.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쾅.png
# Downloaded raw/플레이브밤비/쿵.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/쿵.png
# Downloaded raw/플레이브밤비/탤.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/탤.png
# Downloaded raw/플레이브밤비/턔.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/턔.png
# Downloaded raw/플레이브밤비/토.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/토.png
# Downloaded raw/플레이브밤비/튠.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/튠.png
# Downloaded raw/플레이브밤비/특.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/특.png
# Downloaded raw/플레이브밤비/팼.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/팼.png
# Downloaded raw/플레이브밤비/퍗.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/퍗.png
# Downloaded raw/플레이브밤비/폐.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/폐.png
# Downloaded raw/플레이브밤비/푀.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/푀.png
# Downloaded raw/플레이브밤비/퓸.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/퓸.png
# Downloaded raw/플레이브밤비/핥.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/핥.png
# Downloaded raw/플레이브밤비/홉.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/홉.png
# Downloaded raw/플레이브밤비/횃.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/횃.png
# Downloaded raw/플레이브밤비/훨.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/훨.png
# Downloaded raw/플레이브밤비/ㄱ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄱ.png
# Downloaded raw/플레이브밤비/ㄱㄱ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄱㄱ.png
# Downloaded raw/플레이브밤비/ㄱㅅ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄱㅅ.png
# Downloaded raw/플레이브밤비/ㄴ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄴ.png
# Downloaded raw/플레이브밤비/ㄴㅈ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄴㅈ.png
# Downloaded raw/플레이브밤비/ㄴㅎ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄴㅎ.png
# Downloaded raw/플레이브밤비/ㄷ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄷ.png
# Downloaded raw/플레이브밤비/ㄷㄷ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄷㄷ.png
# Downloaded raw/플레이브밤비/ㄹ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹ.png
# Downloaded raw/플레이브밤비/ㄹㄱ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㄱ.png
# Downloaded raw/플레이브밤비/ㄹㅁ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㅁ.png
# Downloaded raw/플레이브밤비/ㄹㅂ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㅂ.png
# Downloaded raw/플레이브밤비/ㄹㅅ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㅅ.png
# Downloaded raw/플레이브밤비/ㄹㅌ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㅌ.png
# Downloaded raw/플레이브밤비/ㄹㅍ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㅍ.png
# Downloaded raw/플레이브밤비/ㄹㅎ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㄹㅎ.png
# Downloaded raw/플레이브밤비/ㅁ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅁ.png
# Downloaded raw/플레이브밤비/ㅂ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅂ.png
# Downloaded raw/플레이브밤비/ㅂㅂ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅂㅂ.png
# Downloaded raw/플레이브밤비/ㅂㅅ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅂㅅ.png
# Downloaded raw/플레이브밤비/ㅅ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅅ.png
# Downloaded raw/플레이브밤비/ㅅㅅ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅅㅅ.png
# Downloaded raw/플레이브밤비/ㅇ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅇ.png
# Downloaded raw/플레이브밤비/ㅈ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅈ.png
# Downloaded raw/플레이브밤비/ㅈㅈ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅈㅈ.png
# Downloaded raw/플레이브밤비/ㅊ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅊ.png
# Downloaded raw/플레이브밤비/ㅋ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅋ.png
# Downloaded raw/플레이브밤비/ㅌ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅌ.png
# Downloaded raw/플레이브밤비/ㅍ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅍ.png
# Downloaded raw/플레이브밤비/ㅎ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅎ.png
# Downloaded raw/플레이브밤비/ㅏ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅏ.png
# Downloaded raw/플레이브밤비/ㅐ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅐ.png
# Downloaded raw/플레이브밤비/ㅑ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅑ.png
# Downloaded raw/플레이브밤비/ㅒ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅒ.png
# Downloaded raw/플레이브밤비/ㅓ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅓ.png
# Downloaded raw/플레이브밤비/ㅔ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅔ.png
# Downloaded raw/플레이브밤비/ㅕ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅕ.png
# Downloaded raw/플레이브밤비/ㅖ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅖ.png
# Downloaded raw/플레이브밤비/ㅗ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅗ.png
# Downloaded raw/플레이브밤비/ㅘ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅘ.png
# Downloaded raw/플레이브밤비/ㅙ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅙ.png
# Downloaded raw/플레이브밤비/ㅚ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅚ.png
# Downloaded raw/플레이브밤비/ㅛ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅛ.png
# Downloaded raw/플레이브밤비/ㅜ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅜ.png
# Downloaded raw/플레이브밤비/ㅝ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅝ.png
# Downloaded raw/플레이브밤비/ㅞ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅞ.png
# Downloaded raw/플레이브밤비/ㅟ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅟ.png
# Downloaded raw/플레이브밤비/ㅠ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅠ.png
# Downloaded raw/플레이브밤비/ㅡ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅡ.png
# Downloaded raw/플레이브밤비/ㅢ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅢ.png
# Downloaded raw/플레이브밤비/ㅣ.png to /home/jupyter/ai_font/data/test/raw/플레이브밤비/ㅣ.png

# %% [markdown]
# ## Filename Normalize

# %%
import unicodedata
from tqdm import tqdm

fd = f'/home/jupyter/ai_font/data/test/raw/{font}'
files = os.listdir(fd)

for f in tqdm(files):
    oenc = f.encode()
    n = unicodedata.normalize('NFC', f)
    nenc = n.encode()
    if oenc != nenc:
        print(n)
        os.rename(f"{fd}/{f}", f"{fd}/{n}")
# Out:
# 100%|██████████| 132/132 [00:00<00:00, 793192.16it/s]

# %% [markdown]
# ## Preprocess

# %%
import os
import time
import cv2
import numpy as np
from tqdm import tqdm
from PIL import Image

in_fd = f'/home/jupyter/ai_font/data/test/raw/{font}'
out_fd = f'/home/jupyter/ai_font/data/test/processed/{font}'

os.makedirs(out_fd, exist_ok=True)

def augmenting(img):
    img = np.array(img)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(2,2))

    blurred = cv2.GaussianBlur(img, (3, 3), 0)
    processed = cv2.morphologyEx(blurred, cv2.MORPH_CLOSE, kernel)
    closing = Image.fromarray(processed)
    # err = cv2.erode(processed, kernel)
    # erode = Image.fromarray(err)
    # dil = cv2.dilate(processed, kernel)
    # dilate = Image.fromarray(dil)
    return {
        "closing": closing,
        # "erode": erode,
        # "dilate":dilate,
    }

for f in os.listdir(f"{in_fd}"):
    if f.endswith(".png"):
        path = f"{in_fd}/{f}"
        img = Image.open(path).convert("L")
        closing = augmenting(img)['closing']
        closing.save(f"{out_fd}/{font}__closing__{f}")

# %% [markdown]
# ## Testmapper create

# %%
import pandas as pd
def get_all_korean():

    def nextKorLetterFrom(letter):
        lastLetterInt = 15572643
        if not letter:
            return '가'
        a = letter
        b = a.encode('utf8')
        c = int(b.hex(), 16)

        if c == lastLetterInt:
            return False

        d = hex(c + 1)
        e = bytearray.fromhex(d[2:])

        flag = True
        while flag:
            try:
                r = e.decode('utf-8')
                flag = False
            except UnicodeDecodeError:
                c = c+1
                d = hex(c)
                e = bytearray.fromhex(d[2:])
        return e.decode()

    returns = []
    flag = True
    k = ''
    while flag:
        k = nextKorLetterFrom(k)
        if k is False:
            flag = False
        else:
            returns.append(k)
    return returns

def get_lexicon(letter):
    ch1 = (ord(letter) - ord('가'))//588
    ch2 = ((ord(letter) - ord('가')) - (588*ch1)) // 28
    ch3 = (ord(letter) - ord('가')) - (588*ch1) - 28*ch2
    return np.array([ch1, ch2, ch3])

ak = get_all_korean()
testfd = f'/home/jupyter/ai_font/data/test/processed/{font}'
lex_mapper = {}
for k in tqdm(ak):
    lex_mapper[k] = {
        'double': [],
        'single': [],
    }
    
i = 0
for k in tqdm(ak):
    lex_k = get_lexicon(k)
    i += 1
    for l in ak[i:]:
        if not k == l:
            lex_l = get_lexicon(l)
            if np.sum(lex_k == lex_l) == 2:
                lex_mapper[k]['double'].append(l)
                lex_mapper[l]['double'].append(k)
            elif np.sum(lex_k == lex_l) == 1:
                lex_mapper[k]['single'].append(l)
                lex_mapper[l]['single'].append(k)
                
testmap = {}
testmap[font] = {}
for k in ak:
    testmap[font][k] = {
        'double':set(),
        'single':set(),
    }
for f in tqdm(os.listdir(testfd)):
    if f.endswith(".png"):
        font, _, letter = f.split(".")[0].split("__")
        if letter in ak:
            for k in lex_mapper[letter]['double']:
                testmap[font][k]['double'].add(letter)
            for k in lex_mapper[letter]['single']:
                testmap[font][k]['single'].add(letter)
            
testdf = []
for l in ak:
    testdf.append({
        'font': font,
        'letter': l,
        "double": list(testmap[font][l]['double']),
        "single": list(testmap[font][l]['single']),
    })
        
pd.DataFrame().from_dict(testdf).to_pickle(f"/home/jupyter/ai_font/data/pickle/testmap_{font}.pickle")
# Out:
# 100%|██████████| 11172/11172 [00:00<00:00, 100203.93it/s]
# 100%|██████████| 11172/11172 [10:36<00:00, 17.56it/s]
# 100%|██████████| 132/132 [00:00<00:00, 2331.09it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 93
#      85 for l in ak:
#      86     testdf.append({
#      87         'font': font,
#      88         'letter': l,
#      89         "double": list(testmap[font][l]['double']),
#      90         "single": list(testmap[font][l]['single']),
#      91     })
# ---> 93 pd.DataFrame().from_dict(testdf).to_pickle(f"/home/jupyter/ai_font/data/pickle/testmap_{font}.pickle")
#
# NameError: name 'pd' is not defined
